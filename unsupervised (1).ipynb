# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Country-data.csv")

# %%
data.head()
##the helath and bitrh in people help countries in overall development.
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data_ed=data.drop(["country"],axis=1)
x=data_ed

# %%
sns.scatterplot(data=data, x='inflation', y='gdpp')
# Out:
# <AxesSubplot:xlabel='inflation', ylabel='gdpp'>

# %%
sns.pairplot(data,hue='country')
# Out:
# C:\Users\91955\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\91955\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\91955\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\91955\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\91955\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6, random_state=42)

# %%
x
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp
# 0         5.82    553
# 1         1.65   4090
# ...

# %%
model.fit(x)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
model.cluster_centers_
##here the array output 1.77(child_mort) value tells us that child_mort is at a distance to the cnetroid
##same as second cluster 4.3value tells us that it is at a distance to the centroid
# Out:
# array([[1.77357143e+01, 4.38476190e+01, 6.69952381e+00, 4.52071429e+01,
#         1.61576190e+04, 7.26590476e+00, 7.33880952e+01, 2.06785714e+00,
#         8.94761905e+03],
#        [4.32500000e+00, 4.55687500e+01, 1.08893750e+01, 4.17625000e+01,
#         4.23312500e+04, 1.09112500e+00, 8.08375000e+01, 1.80000000e+00,
#         4.85375000e+04],
#        [5.00000000e+00, 9.23333333e+01, 6.35333333e+00, 6.47666667e+01,
#         9.30000000e+04, 5.51666667e+00, 8.06000000e+01, 1.88333333e+00,
#         8.77000000e+04],
#        [1.28833333e+01, 5.54666667e+01, 7.44500000e+00, 5.07833333e+01,
#         3.21833333e+04, 5.18388889e+00, 7.76055556e+01, 2.05111111e+00,
#         2.39166667e+04],
#        [8.17500000e+00, 1.02950000e+02, 3.27250000e+00, 7.40000000e+01,
#         7.13750000e+04, 1.00885000e+01, 7.86250000e+01, 1.76750000e+00,
#         3.88500000e+04],
#        [6.30642857e+01, 3.10392738e+01, 6.14821429e+00, 4.59448321e+01,
# ...

# %%
preds = model.predict(x)
preds
# Out:
# array([5, 5, 0, 5, 0, 0, 5, 1, 1, 0, 3, 3, 5, 0, 0, 1, 5, 5, 5, 5, 5, 0,
#        0, 4, 0, 5, 5, 5, 5, 1, 5, 5, 5, 0, 5, 0, 5, 5, 5, 0, 5, 0, 3, 3,
#        1, 0, 5, 5, 5, 3, 5, 0, 5, 1, 1, 0, 5, 5, 1, 5, 3, 0, 5, 5, 5, 5,
#        5, 0, 1, 5, 5, 0, 0, 1, 3, 3, 5, 1, 5, 0, 5, 5, 4, 5, 5, 0, 0, 5,
#        5, 3, 0, 2, 0, 5, 5, 0, 0, 5, 3, 5, 0, 5, 5, 5, 0, 5, 5, 5, 5, 5,
#        1, 3, 5, 5, 2, 3, 5, 0, 5, 5, 5, 0, 3, 2, 0, 0, 5, 5, 3, 5, 0, 0,
#        5, 4, 3, 3, 5, 0, 3, 3, 5, 0, 5, 0, 1, 1, 5, 5, 0, 5, 5, 5, 5, 0,
#        5, 5, 5, 4, 1, 1, 0, 5, 5, 0, 5, 5, 5])

# %%
##We can check the "goodness" of the fit by looking at model.inertia_, which contains the sum of squared distances of samples to their closest cluster center. Lower the inertia, better the fit.
model.inertia_
# Out:
# 7655725089.094505

# %%
#find the best total no of clusters by using elbow method at 6 clusters we will get less inertia(accuracy value)
options = range(2,11)
inertias = []

for n_clusters in options:
    model = KMeans(n_clusters, random_state=42).fit(x)
    inertias.append(model.inertia_)
    
plt.title("No. of clusters vs. Inertia")
plt.plot(options, inertias, '-o')
plt.xlabel('No. of clusters (K)')
plt.ylabel('Inertia');
